# %%
import pandas as pd

# %%
dataset=pd.read_excel("C:/Users/Dell/Desktop/data.xlsx")
dataset
# Out:
#     Veer Madho Singh Bhandari Uttarakhand Technical University Dehradun  \
# 0    Seat Matrix For Admission in B. Tech. (First Y...
# 1    GEN-General, EWS-Economically Weaker Section, ...
# 2    OP-Open, PH- Physicaly Handicapped, AF- Depend...
# 3                                              ROUND-1
# 4                                                   SN
# ..                                                 ...
# 162                                                NaN
# 163                                                109
# 164                                                110
# 165                                                111
# 166                                                112
#
#                      Unnamed: 1  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                INSTITUTE NAME
# ..                          ...
# 162                         NaN
# ...

# %%
df=dataset.iloc[7:,1:5]
df
# Out:
#                                             Unnamed: 1  \
# 7    BIPINTRIPATHI KUMAON INSTITUTE OF\nTECHNOLOGY,...
# 8    BIPINTRIPATHI KUMAON INSTITUTE OF TECHNOLOGY, ...
# 9    BIPINTRIPATHI KUMAON INSTITUTE OF TECHNOLOGY, ...
# 10   BIPINTRIPATHI KUMAON INSTITUTE OF TECHNOLOGY, ...
# 11   BIPINTRIPATHI KUMAON INSTITUTE OF TECHNOLOGY, ...
# ..                                                 ...
# 162                                                NaN
# 163                         TULA`S INSTITUTE, DEHRADUN
# 164                         TULA`S INSTITUTE, DEHRADUN
# 165                         TULA`S INSTITUTE, DEHRADUN
# 166                         TULA`S INSTITUTE, DEHRADUN
#
#                                          Unnamed: 2 Unnamed: 3 Unnamed: 4
# 7                                     BIOTECHNOLOGY          G         30
# 8                              CHEMICAL ENGINEERING          G         30
# 9                                 CIVIL ENGINEERING          G         60
# ...

# %%
cswale=df[df['Unnamed: 2'].str.contains('COMPUTER SCIENCE ',case=False,na=False)]
itwale=df[df['Unnamed: 2'].str.contains('INFORMATION ',case=False,na=False)]
rdwale=df[df['Unnamed: 2'].str.contains('ROBOTICS',case=False,na=False)]
cbwale=[df['Unnamed: 2'].str.contains('CYBER SECURITY',case=False,na=False)]

# %%
cbwale
# Out:
# [7      False
#  8      False
#  9      False
#  10     False
#  11     False
#         ...
#  162      NaN
#  163    False
#  164    False
#  165    False
#  166    False
#  Name: Unnamed: 2, Length: 160, dtype: object]
